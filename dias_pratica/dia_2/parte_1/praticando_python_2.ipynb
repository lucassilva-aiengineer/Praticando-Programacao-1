# %%
def operadores():

    # O in verifica se um elemento está contido em uma estrutura de dados 

    lista = [10, 20, 30]
    print("O número 20 está na lista: ", 20 in lista)

    print(10 is 10)

    dicionario_1 = dict()
    dicionario_2 = dict()

    # O is verifica se dois objetos são iguais.

    print(dicionario_1 is dicionario_2)
# Out:
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\lucas_e9hwi00\AppData\Local\Temp\ipykernel_21104\4093602842.py:8: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(10 is 10)

# %%
def entrada_user()-> None:

    idade = int(input("Indique quantos anos você tem: "))
    print(idade)

# %%
def main():

    # operadores()
    entrada_user()

# %%
main()
